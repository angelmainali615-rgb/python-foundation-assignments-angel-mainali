# %% [markdown]
# # Stretch: Contact Book Menu

# %%
# Stretch Exercise: Contact Book Menu

contacts = {}  # key: name, value: nested dict with phone and email

while True:
    print("\nContact Book Menu")
    print("1. Add contact")
    print("2. Search contact")
    print("3. Delete contact")
    print("4. Display all contacts")
    print("5. Exit")
    
    choice = input("Enter your choice (1-5): ").strip()
    
    if choice == "1":
        # Add contact
        name = input("Enter name: ").strip()
        phone = input("Enter phone number: ").strip()
        email = input("Enter email address: ").strip()
        
        contacts[name] = {
            "phone": phone,
            "email": email
        }
        print(f"Contact for {name} added/updated.")
    
    elif choice == "2":
        # Search contact
        name = input("Enter name to search: ").strip()
        if name in contacts:
            details = contacts[name]
            print(f"Name: {name}")
            print(f"Phone: {details['phone']}")
            print(f"Email: {details['email']}")
        else:
            print("Contact not found.")
    
    elif choice == "3":
        # Delete contact
        name = input("Enter name to delete: ").strip()
        if name in contacts:
            del contacts[name]
            print(f"Contact for {name} deleted.")
        else:
            print("Contact not found. Nothing to delete.")
    
    elif choice == "4":
        # Display all contacts
        if not contacts:
            print("No contacts to display.")
        else:
            print("\nAll contacts:")
            for name, details in contacts.items():
                print(f"- {name}: Phone = {details['phone']}, Email = {details['email']}")
    
    elif choice == "5":
        # Exit
        print("Exiting contact book. Goodbye!")
        break
    
    else:
        print("Invalid choice. Please enter a number from 1 to 5.")
# Out:
# Contact Book Menu
# 1. Add contact
# 2. Search contact
# 3. Delete contact
# 4. Display all contacts
# 5. Exit
# Enter your choice (1-5):  1
# Enter name:  Angel
# Enter phone number:  9827243366
# Enter email address:  angelmainali765@gmail.com
# Contact for Angel added/updated.
#
# Contact Book Menu
# 1. Add contact
# 2. Search contact
# 3. Delete contact
# 4. Display all contacts
# 5. Exit
# Enter your choice (1-5):  4
# All contacts:
# - Angel: Phone = 9827243366, Email = angelmainali765@gmail.com
#
# Contact Book Menu
# 1. Add contact
# 2. Search contact
# 3. Delete contact
# 4. Display all contacts
# 5. Exit
# Enter your choice (1-5):  2
# Enter name to search:  angel
# Contact not found.
#
# Contact Book Menu
# 1. Add contact
# 2. Search contact
# 3. Delete contact
# 4. Display all contacts
# 5. Exit
# Enter your choice (1-5):  Angel
# Invalid choice. Please enter a number from 1 to 5.
#
# Contact Book Menu
# 1. Add contact
# 2. Search contact
# 3. Delete contact
# 4. Display all contacts
# 5. Exit
# Enter your choice (1-5):  2
# Enter name to search:  Angel
# Name: Angel
# Phone: 9827243366
# Email: angelmainali765@gmail.com
#
# Contact Book Menu
# 1. Add contact
# 2. Search contact
# 3. Delete contact
# 4. Display all contacts
# 5. Exit
# Enter your choice (1-5):  3
# Enter name to delete:  Angel
# Contact for Angel deleted.
#
# Contact Book Menu
# 1. Add contact
# 2. Search contact
# 3. Delete contact
# 4. Display all contacts
# 5. Exit
# Enter your choice (1-5):  4
# No contacts to display.
#
# Contact Book Menu
# 1. Add contact
# 2. Search contact
# 3. Delete contact
# 4. Display all contacts
# 5. Exit
# Enter your choice (1-5):  5
# Exiting contact book. Goodbye!
