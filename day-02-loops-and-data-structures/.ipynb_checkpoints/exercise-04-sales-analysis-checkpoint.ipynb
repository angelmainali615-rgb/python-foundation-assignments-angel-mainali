# %% [markdown]
# # Exercise 4: Sales List Analysis

# %%
monthly_sales = [85000, 120000, 95000, 140000, 75000, 160000]

# %%
# 1. Sorted list from highest to lowest
sorted_sales_desc = sorted(monthly_sales, reverse=True)
print("Sorted (desc):", sorted_sales_desc)

# 2. Values above 100000
high_sales = [amount for amount in monthly_sales if amount > 100000]
print("Above 100000:", high_sales)

# 3. Add 13% tax to each
sales_with_tax = [amount * 1.13 for amount in monthly_sales]
print("With 13% tax:", sales_with_tax)

# 4. Total sales
total_sales = sum(monthly_sales)
print("Total sales:", total_sales)

# 5. Average sales
average_sales = total_sales / len(monthly_sales)
print("Average sales:", average_sales)
# Out:
# Sorted (desc): [160000, 140000, 120000, 95000, 85000, 75000]
# Above 100000: [160000, 140000, 120000]
# With 13% tax: [180799.99999999997, 158199.99999999997, 135600.0, 107349.99999999999, 96049.99999999999, 84749.99999999999]
# Total sales: 675000
# Average sales: 112500.0
